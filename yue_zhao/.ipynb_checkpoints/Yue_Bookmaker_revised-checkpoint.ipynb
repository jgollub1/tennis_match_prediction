# %%
import pandas as pd
df=pd.read_excel("tny.xlsx")
df = df.rename(columns={'winner':'w_name','loser':'l_name','tourney_year_id':'tny_id',\
                           'tourney_name_x':'tny_name','start_date':'tny_date','match_index':'match_num'})
df['match_num'] = df['match_num'].astype(str)
df['match_num'] = [s.replace('MS','') for s in df['match_num']]
df['tny_date'] = df['tny_date'].astype(str)
df['tny_date'] = [s.replace('.','') for s in df['tny_date']]

# %%
df['tny_name'] = ['Davis Cup' if 'Davis Cup' in s else s for s in df['tny_name']]
df['tny_name'] = [s.replace('Australian Chps.','Australian Open').replace('Australian Open-2',\
            'Australian Open').replace('U.S. National Chps.','US Open') for s in df['tny_name']]

# %%
import datetime
import re
def normalize_name(s,tour='atp'):
    if tour=='atp':
        s = s.replace('-',' ')
        s = s.replace('Stanislas','Stan').replace('Stan','Stanislas')
        s = s.replace('Alexandre','Alexander')
        s = s.replace('Federico Delbonis','Federico Del').replace('Federico Del','Federico Delbonis')
        s = s.replace('Mello','Melo')
        s = s.replace('Cedric','Cedrik')
        s = s.replace('Bernakis','Berankis')
        s = s.replace('Hansescu','Hanescu')
        s = s.replace('Teimuraz','Teymuraz')
        s = s.replace('Vikor','Viktor')
        s = s.rstrip()
        s = s.replace('Alex Jr.','Alex Bogomolov')
        s = s.title()
        sep = s.split(' ')
        return ' '.join(sep[:2]) if len(sep)>2 else s
    else:
        return s


TOUR='atp'
df['w_name'] = [normalize_name(x,tour=TOUR) for x in df['w_name']]
df['l_name'] = [normalize_name(x,tour=TOUR) for x in df['l_name']]
df['tny_name'] = ['Davis Cup' if 'Davis Cup' in s else s for s in df['tny_name']]
df['tny_name'] = [s.replace('Australian Chps.','Australian Open').replace('Australian Open-2',\
	            'Australian Open').replace('U.S. National Chps.','US Open') for s in df['tny_name']]

def format_match_df(df,ret_strings=[],abd_strings=[]):
    #df['pbp'] = [None]*len(df)
    df = df[~df['tny_date'].isin(['nan'])]
    #df = df.dropna(subset=['tny_date'])
    df = df.rename(columns={'winner_name':'w_name','loser_name':'l_name'})
    grand_slam_d = dict(zip(['Australian Open','Roland Garros','Wimbledon','US Open'],[1]*4))
    df['is_gs'] = [name in grand_slam_d for name in df['tny_name']]

    # Get dates into the same format
    df['tny_date'] = [datetime.datetime.strptime(str(x), "%Y%m%d").date() for x in df['tny_date']]
    df['match_year'] = [x.year for x in df['tny_date']]
    df['match_month'] = [x.month for x in df['tny_date']]
    df['score'] = [re.sub(r"[\(\[].*?[\)\]]", "", str(s)) for s in df['score']] # str(s) fixes any nans
    df['score'] = ['RET' if 'RET' in s else s for s in df['score']]
    df['w_swon'] = df['winner_first_serve_points_won'] + df['winner_second_serve_points_won'] 
    df['l_swon'] = df['loser_first_serve_points_won'] + df['loser_second_serve_points_won']
    df['w_rwon'] = df['winner_first_serve_return_won'] + df['winner_second_serve_return_won']
    df['l_rwon'] = df['loser_first_serve_return_won'] + df['loser_second_serve_return_won']
    df['w_rpt'] = df['winner_first_serve_return_total'] + df['winner_second_serve_return_total']
    df['l_rpt'] = df['loser_first_serve_return_total'] + df['loser_second_serve_return_total']

    # get rid of leading 0s in tny_id
    df['tny_id'] = ['-'.join(t.split('-')[:-1] + [t.split('-')[-1][1:]]) if t.split('-')[-1][0]=='0' else t \
                                    for t in df['tny_id']]

    # get rid of matches involving a retirement
    #df['score'] = ['ABN' if score.split(' ')[-1] in ('abandoned','ABN','ABD','DEF','def','unfinished','Walkover') \
    #                            else score for score in df['score']]
    #ret_strings = ['ABN','DEF','In Progress','RET','W/O',' RET',' W/O','nan','walkover']
    #ret_d = dict(zip(ret_strings,[1]*len(ret_strings)))
    #df = df.loc[[i for i in range(len(df)) if df['score'][i] not in ret_d]]
    df = df.sort_values(by=['tny_date','tny_name','match_num'], ascending=True).reset_index()
    del df['index']; return df

# %%
ret_strings = ('ABN','DEF','In Progress','RET','W/O',' RET',' W/O','nan','walkover')
abd_strings = ('abandoned','ABN','ABD','DEF','def','unfinished','Walkover')
atp_all_matches = format_match_df(df,ret_strings=ret_strings,abd_strings=abd_strings)
atp_all_matches = atp_all_matches[['tny_id','tny_name','tny_date','match_num','surface','is_gs','w_name','l_name',
                'winner_player_id','loser_player_id','tourney_round_name','match_year','match_month','score']]

# %%
print atp_all_matches.shape
atp_all_matches.head()
# Out:
# (74886, 14)
#       tny_id  tny_name    tny_date match_num surface  is_gs  \
# 0  2001-7308  Adelaide  2001-01-01       001    Hard  False
# 1  2001-7308  Adelaide  2001-01-01       002    Hard  False
# 2  2001-7308  Adelaide  2001-01-01       003    Hard  False
# 3  2001-7308  Adelaide  2001-01-01       004    Hard  False
# 4  2001-7308  Adelaide  2001-01-01       005    Hard  False
#
#               w_name             l_name winner_player_id loser_player_id  \
# 0         Tommy Haas      Nicolas Massu             h355            m655
# 1         Tommy Haas  Jason Stoltenberg             h355            s331
# 2      Nicolas Massu         Tim Henman             m655            h336
# 3         Tommy Haas     Lleyton Hewitt             h355            h432
# 4  Jason Stoltenberg     Alberto Martin             s331            m590
#
#   tourney_round_name  match_year  match_month        score
# 0             Finals        2001            1      6-3 6-1
# 1        Semi-Finals        2001            1      7-6 6-4
# 2        Semi-Finals        2001            1  3-6 7-5 6-2
# 3     Quarter-Finals        2001            1  6-4 0-6 6-1
# 4     Quarter-Finals        2001            1      6-3 6-4

# %%
# tnynametest = atp_all_matches
# grandslam = 0.0
# tourfinals = 0.0
# masters = 0.0
# olympics = 0.0
# othergames = 0.0
# for i in range(len(tnynametest)):
#     if "Grand Slam" in tnynametest['tny_name'][i]:
#         grandslam = grandslam + 1.0
#     elif "Tour Finals" in tnynametest['tny_name'][i]:
#         tourfinals = tourfinals + 1.0
#     elif "Masters" in tnynametest['tny_name'][i]:
#         masters = masters + 1.0
#     elif "Olympics" in tnynametest['tny_name'][i]:
#         olympics = olympics + 1.0
#     else:
#         othergames = othergames + 1.0
        
# print grandslam, tourfinals, masters, olympics, othergames

# %% [markdown]
# ## Split the training and test data

# %%
c = 2015
test_yr = 2016
train_df,test_df = atp_all_matches[atp_all_matches['match_year']<=c],atp_all_matches[atp_all_matches['match_year']==test_yr]
print len(train_df)
print len(test_df)
# Out:
# 58502
# 16384

# %%
import numpy as np
# import elo_538 as elo
import elo_538_jy as elo

COUNT = 0
players_list = np.union1d(train_df.w_name, train_df.l_name)
players_elo = dict(zip(list(players_list), [elo.Rating() for __ in range(len(players_list))]))
surface_elo = {}
for surface in ('Hard','Clay','Grass'):
    surface_elo[surface] = dict(zip(list(players_list), [elo.Rating() for __ in range(len(players_list))])) 

elo_1s, elo_2s = [],[]
surface_elo_1s, surface_elo_2s = [],[]
elo_obj = elo.Elo_Rater()

for i, row in train_df.iterrows():
    surface = row['surface']; is_gs = row['is_gs']
    # append elos, rate, update
    w_elo,l_elo = players_elo[row['w_name']],players_elo[row['l_name']]
    elo_1s.append(w_elo.value);elo_2s.append(l_elo.value)    
    
#     elo_obj.rate_1vs1(w_elo,l_elo,is_gs,counts=COUNT)
    elo_obj.rate_1vs1(w_elo,l_elo,is_gs,counts=COUNT, tny_name=row['tny_name'], tny_round_name=row['tourney_round_name'])

    
#     surface_elo_1s.append(surface_elo[surface][row['w_name']].value if surface in ('Hard','Clay','Grass') else w_elo.value)
#     surface_elo_2s.append(surface_elo[surface][row['l_name']].value if surface in ('Hard','Clay','Grass') else l_elo.value)
#     if surface in ('Hard','Clay','Grass'):
#         new_elo1, new_elo2 = elo_obj.rate_1vs1(surface_elo[surface][row['w_name']],surface_elo[surface][row['l_name']],is_gs,counts=COUNT)

# add columns
train_df['w_elo'], train_df['l_elo'] = elo_1s, elo_2s
# train_df['sw_elo'], train_df['sl_elo'] = surface_elo_1s, surface_elo_2s
# Out:
# /Users/jingyaxun/Library/Python/2.7/lib/python/site-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
COUNT = 1
players_list = np.union1d(train_df.w_name, train_df.l_name)
players_elo = dict(zip(list(players_list), [elo.Rating() for __ in range(len(players_list))]))
surface_elo = {}
for surface in ('Hard','Clay','Grass'):
    surface_elo[surface] = dict(zip(list(players_list), [elo.Rating() for __ in range(len(players_list))])) 

elo_1s, elo_2s = [],[]
surface_elo_1s, surface_elo_2s = [],[]
elo_obj = elo.Elo_Rater()

for i, row in train_df.iterrows():
    surface = row['surface']; is_gs = row['is_gs']
    # append elos, rate, update
    w_elo,l_elo = players_elo[row['w_name']],players_elo[row['l_name']]
    elo_1s.append(w_elo.value);elo_2s.append(l_elo.value)    
    
#     elo_obj.rate_1vs1(w_elo,l_elo,is_gs,counts=COUNT)
    elo_obj.rate_1vs1(w_elo,l_elo,is_gs,counts=COUNT, tny_name=row['tny_name'], tny_round_name=row['tourney_round_name'])
    
#     surface_elo_1s.append(surface_elo[surface][row['w_name']].value if surface in ('Hard','Clay','Grass') else w_elo.value)
#     surface_elo_2s.append(surface_elo[surface][row['l_name']].value if surface in ('Hard','Clay','Grass') else l_elo.value)
#     if surface in ('Hard','Clay','Grass'):
#         new_elo1, new_elo2 = elo_obj.rate_1vs1(surface_elo[surface][row['w_name']],surface_elo[surface][row['l_name']],is_gs,counts=COUNT)

# add columns
train_df['w_elo_538'], train_df['l_elo_538'] = elo_1s, elo_2s
# train_df['w_sf_elo_538'], train_df['l_sf_elo_538'] = surface_elo_1s, surface_elo_2s
# Out:
# /Users/jingyaxun/Library/Python/2.7/lib/python/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# # New Testing method
# COUNT = 1
# players_list = np.union1d(atp_all_matches.w_name, atp_all_matches.l_name)
# players_elo = dict(zip(list(players_list), [elo.Rating() for __ in range(len(players_list))]))
# surface_elo = {}
# # for surface in ('Hard','Clay','Grass'):
# #     surface_elo[surface] = dict(zip(list(players_list), [elo.Rating() for __ in range(len(players_list))])) 

# elo_1s, elo_2s = [],[]
# # surface_elo_1s, surface_elo_2s = [],[]
# elo_obj = elo.Elo_Rater()
# correct_num = 0

# test_df_cpy = test_df.copy()

# for i, row in test_df.iterrows():
    
#     test_df_cpy = generate_elo_test(test_df_cpy, 0)
#     test_df_cpy = generate_elo_test(test_df_cpy, 1)
    
    
#     ###############
#     surface = row['surface']; is_gs = row['is_gs']
#     # append elos, rate, update
#     w_elo,l_elo = players_elo[row['w_name']],players_elo[row['l_name']]
#     # print("w_elo: {}, l_elo: {}, i: {}".format(w_elo.value, l_elo.value, i))
#     if (w_elo.value > l_elo.value):
#         correct_num += 1
#     elo_1s.append(w_elo.value);elo_2s.append(l_elo.value)    
    
#     elo_obj.rate_1vs1(w_elo,l_elo,is_gs,counts=COUNT, tny_name=row['tny_name'], tny_round_name=row['tourney_round_name'])

    
#     # surface_elo_1s.append(surface_elo[surface][row['w_name']].value if surface in ('Hard','Clay','Grass') else w_elo.value)
#     # surface_elo_2s.append(surface_elo[surface][row['l_name']].value if surface in ('Hard','Clay','Grass') else l_elo.value)
#     # if surface in ('Hard','Clay','Grass'):
#     #     new_elo1, new_elo2 = elo_obj.rate_1vs1(surface_elo[surface][row['w_name']],surface_elo[surface][row['l_name']],is_gs,counts=COUNT)

# # add columns
# atp_all_matches['w_elo_538'], atp_all_matches['l_elo_538'] = elo_1s, elo_2s
# # atp_all_matches['w_sf_elo_538'], atp_all_matches['l_sf_elo_538'] = surface_elo_1s, surface_elo_2s

# print(float(correct_num)/16384)

# %%
# #rankings

rankings = sorted(zip(players_elo.keys(),players_elo.values()),key=lambda x: x[1].value,reverse=True)
rankings
# Out:
# [(u'Novak Djokovic', elo_538_jy.Rating(2844.168, times=1222)),
#  (u'Roger Federer', elo_538_jy.Rating(2664.759, times=1670)),
#  (u'Rafael Nadal', elo_538_jy.Rating(2588.385, times=1351)),
#  (u'Andy Murray', elo_538_jy.Rating(2494.595, times=886)),
#  (u'Stanislas Wawrinka', elo_538_jy.Rating(2417.909, times=691)),
#  (u'Kei Nishikori', elo_538_jy.Rating(2387.724, times=433)),
#  (u'Juan Martin', elo_538_jy.Rating(2379.705, times=440)),
#  (u'Tomas Berdych', elo_538_jy.Rating(2374.322, times=923)),
#  (u'Robin Soderling', elo_538_jy.Rating(2365.279, times=506)),
#  (u'David Ferrer', elo_538_jy.Rating(2347.448, times=1139)),
#  (u'Richard Gasquet', elo_538_jy.Rating(2344.694, times=740)),
#  (u'Jo Wilfried', elo_538_jy.Rating(2333.047, times=589)),
#  (u'Milos Raonic', elo_538_jy.Rating(2312.754, times=324)),
#  (u'Marin Cilic', elo_538_jy.Rating(2291.022, times=563)),
#  (u'Kevin Anderson', elo_538_jy.Rating(2266.058, times=466)),
#  (u'John Isner', elo_538_jy.Rating(2259.380, times=498)),
#  (u'Tobias Simon', elo_538_jy.Rating(1793.127, times=8)),
#  (u'Axel Pretzsch', elo_538_jy.Rating(1793.118, times=15)),
#  (u'Aisam Ul', elo_538_jy.Rating(1793.106, times=54)),
#  (u'Chase Buchanan', elo_538_jy.Rating(1793.087, times=28)),
#  (u'Jeff Dadamo', elo_538_jy.Rating(1793.015, times=7)),
#  (u'Francisco Bahamonde', elo_538_jy.Rating(1792.996, times=3)),
#  (u'Goran Ivanisevic', elo_538_jy.Rating(1792.447, times=74)),
#  (u'Miles Armstrong', elo_538_jy.Rating(1792.419, times=4)),
#  (u'Jason Jung', elo_538_jy.Rating(1792.346, times=19)),
#  (u'Slimane Saoudi', elo_538_jy.Rating(1792.251, times=6)),
#  (u'Roman Jebavy', elo_538_jy.Rating(1792.191, times=5)),
#  (u'Colin Ebelthite', elo_538_jy.Rating(1792.020, times=15)),
#  (u'Alberto Francis', elo_538_jy.Rating(1791.610, times=10)),
#  (u'Fred Simonsson', elo_538_jy.Rating(1791.568, times=10)),
#  (u'Byron Black', elo_538_jy.Rating(1791.533, times=25)),
#  (u'Aoran Wang', elo_538_jy.Rating(1791.456, times=4)),
#  (u'Marcelo Melo', elo_538_jy.Rating(1791.372, times=17)),
#  (u'Mark Nielsen', elo_538_jy.Rating(1791.232, times=8)),
#  (u'Michal Wlodarczyk', elo_538_jy.Rating(1791.168, times=3)),
#  (u'Dino Marcan', elo_538_jy.Rating(1790.747, times=19)),
#  (u'Flavio Cipolla', elo_538_jy.Rating(1790.366, times=239)),
#  (u'Martin Emmrich', elo_538_jy.Rating(1790.132, times=9)),
#  (u'Nick Lindahl', elo_538_jy.Rating(1789.943, times=41)),
#  (u'Rui Machado', elo_538_jy.Rating(1788.812, times=96)),
#  (u'Uros Vico', elo_538_jy.Rating(1788.689, times=13)),
#  (u'Navdeep Singh', elo_538_jy.Rating(1788.353, times=6)),
#  (u'Dennis Van', elo_538_jy.Rating(1788.275, times=47)),
#  (u'Vadim Kutsenko', elo_538_jy.Rating(1787.908, times=10)),
#  (u'Chayanon Kaewsuto', elo_538_jy.Rating(1787.875, times=4)),
#  (u'Oliver Golding', elo_538_jy.Rating(1787.789, times=16)),
#  (u'Sasa Tuksar', elo_538_jy.Rating(1787.665, times=10)),
#  (u'Konstantinos Economidis', elo_538_jy.Rating(1787.646, times=23)),
#  (u'Amer Delic', elo_538_jy.Rating(1787.539, times=131)),
#  (u'Takao Suzuki', elo_538_jy.Rating(1787.503, times=57)),
#  (u'Ivan Endara', elo_538_jy.Rating(1786.243, times=5)),
#  (u'Guillermo Hormazabal', elo_538_jy.Rating(1786.194, times=12)),
#  (u'Olivier Sajous', elo_538_jy.Rating(1786.112, times=17)),
#  (u'James Auckland', elo_538_jy.Rating(1785.980, times=8)),
#  (u'Andriej Kapas', elo_538_jy.Rating(1785.901, times=6)),
#  (u'Stefano Napolitano', elo_538_jy.Rating(1785.774, times=9)),
#  (u'Stefan Kozlov', elo_538_jy.Rating(1785.719, times=12)),
#  (u'Martin Verkerk', elo_538_jy.Rating(1785.613, times=119)),
#  (u'Laslo Djere', elo_538_jy.Rating(1785.522, times=13)),
#  (u'Blazej Koniusz', elo_538_jy.Rating(1785.223, times=5)),
#  (u'Blake Strode', elo_538_jy.Rating(1785.139, times=14)),
#  (u'Kento Takeuchi', elo_538_jy.Rating(1784.858, times=6)),
#  (u'Dennis Novak', elo_538_jy.Rating(1784.679, times=18)),
#  (u'Rasmus Moller', elo_538_jy.Rating(1784.489, times=3)),
#  (u'Liam Broady', elo_538_jy.Rating(1783.839, times=22)),
#  (u'Francisco Clavet', elo_538_jy.Rating(1783.641, times=92)),
#  (u'Evgeny Elistratov', elo_538_jy.Rating(1783.525, times=6)),
#  (u'Mladen Mitak', elo_538_jy.Rating(1783.299, times=5)),
#  (u'Alexander Ritschard', elo_538_jy.Rating(1783.285, times=7)),
#  (u'Jan Frode', elo_538_jy.Rating(1783.169, times=10)),
#  (u'Jaan Frederik', elo_538_jy.Rating(1783.100, times=13)),
#  (u'Michal Schmid', elo_538_jy.Rating(1782.738, times=5)),
#  (u"Kaes Van'T", elo_538_jy.Rating(1782.670, times=3)),
#  (u'Angel Torres', elo_538_jy.Rating(1782.622, times=3)),
#  (u'Mohammed Fetov', elo_538_jy.Rating(1782.351, times=3)),
#  (u'Federico Browne', elo_538_jy.Rating(1782.275, times=17)),
#  (u'Alexander Slabinsky', elo_538_jy.Rating(1782.213, times=17)),
#  (u'Oskar Pallin', elo_538_jy.Rating(1782.146, times=4)),
#  (u'Federico Luzzi', elo_538_jy.Rating(1782.043, times=51)),
#  (u'Drake Bernstein', elo_538_jy.Rating(1782.002, times=5)),
#  (u'Sergio Galdos', elo_538_jy.Rating(1781.789, times=4)),
#  (u'Jamie Cerretani', elo_538_jy.Rating(1781.569, times=5)),
#  (u'Jiri Vanek', elo_538_jy.Rating(1781.479, times=180)),
#  (u'Maxim Dubarenco', elo_538_jy.Rating(1781.137, times=10)),
#  (u'Luca Schena', elo_538_jy.Rating(1780.832, times=3)),
#  (u'Robert Lindstedt', elo_538_jy.Rating(1780.771, times=3)),
#  (u'Matias Sborowitz', elo_538_jy.Rating(1780.652, times=5)),
#  (u'Alex Bolt', elo_538_jy.Rating(1780.615, times=28)),
#  (u'Wilson Leite', elo_538_jy.Rating(1780.224, times=10)),
#  (u'Bohdan Ulihrach', elo_538_jy.Rating(1780.115, times=163)),
#  (u'Marcos Daniel', elo_538_jy.Rating(1780.053, times=93)),
#  (u'Daniel Nestor', elo_538_jy.Rating(1779.776, times=15)),
#  (u'Di Wu', elo_538_jy.Rating(1779.744, times=39)),
#  (u'Hugo Dellien', elo_538_jy.Rating(1779.265, times=5)),
#  (u'Daniel Cox', elo_538_jy.Rating(1779.065, times=39)),
#  (u'Gregoire Barrere', elo_538_jy.Rating(1778.470, times=6)),
#  (u'Filip Veger', elo_538_jy.Rating(1778.451, times=21)),
#  (u'Nathan Healey', elo_538_jy.Rating(1778.367, times=28)),
#  (u'Victor Crivoi', elo_538_jy.Rating(1778.286, times=108)),
#  (u'Brian Wilson', elo_538_jy.Rating(1778.165, times=8)),
#  (u'Matwe Middelkoop', elo_538_jy.Rating(1760.208, times=55)),
#  (u'Goran Tosic', elo_538_jy.Rating(1760.103, times=16)),
#  (u'Henrik Norfeldt', elo_538_jy.Rating(1760.101, times=4)),
#  (u'Chris Wettengel', elo_538_jy.Rating(1759.568, times=17)),
#  (u'Jeff Morrison', elo_538_jy.Rating(1759.421, times=81)),
#  (u'Daniel Vacek', elo_538_jy.Rating(1759.042, times=12)),
#  (u'Marin Bradaric', elo_538_jy.Rating(1759.025, times=3)),
#  (u'Olivier Charroin', elo_538_jy.Rating(1758.862, times=9)),
#  (u'Joel Lindner', elo_538_jy.Rating(1758.331, times=3)),
#  (u'Alessio Di', elo_538_jy.Rating(1758.095, times=69)),
#  (u'John Peers', elo_538_jy.Rating(1757.949, times=10)),
#  (u'Tudor Dumitrescu', elo_538_jy.Rating(1757.440, times=3)),
#  (u'James Marsalek', elo_538_jy.Rating(1757.154, times=9)),
#  (u'Alexander Reichel', elo_538_jy.Rating(1756.945, times=5)),
#  (u'Michal Mertinak', elo_538_jy.Rating(1756.665, times=42)),
#  (u'Kyu Tae', elo_538_jy.Rating(1756.375, times=23)),
#  (u'Vladimir Voltchkov', elo_538_jy.Rating(1756.318, times=83)),
#  (u'Marc Kevin', elo_538_jy.Rating(1756.220, times=13)),
#  (u'Mathieu Rodrigues', elo_538_jy.Rating(1756.091, times=28)),
#  (u'Skander Mansouri', elo_538_jy.Rating(1755.708, times=3)),
#  (u'Eduardo Struvay', elo_538_jy.Rating(1755.518, times=6)),
#  (u'Fajing Sun', elo_538_jy.Rating(1755.236, times=4)),
#  (u'Andrea Agazzi', elo_538_jy.Rating(1755.236, times=6)),
#  (u'Todd Woodbridge', elo_538_jy.Rating(1755.197, times=11)),
#  (u'Lucas Arnold', elo_538_jy.Rating(1755.066, times=3)),
#  (u'Glenn Weiner', elo_538_jy.Rating(1755.011, times=30)),
#  (u'Yves Allegro', elo_538_jy.Rating(1754.271, times=24)),
#  (u'Rohan Gajjar', elo_538_jy.Rating(1753.716, times=7)),
#  (u'Jeevan Nedunchezhiyan', elo_538_jy.Rating(1753.572, times=7)),
#  (u'Marko Tkalec', elo_538_jy.Rating(1753.013, times=15)),
#  ...]

# %%
list1 = []
list2 = []
for i in range(len(test_df)):
    
    name = test_df['w_name'][i+58502]
    if name in players_elo.keys():
        if name not in list1:
            list1.append(name)
    else:
        if name not in list2:
            list2.append(name)

print len(list1)
print len(list2)
list1

# for s in list1:
#     print players_elo[s]

df_test1 = test_df

for s in list2:
    df_test1 = df_test1[df_test1.w_name != s]
    df_test1 = df_test1[df_test1.l_name != s]
    
df_test2 = df_test1
df_test2.reset_index(drop=True,inplace=True)
df_test2

sumofright = 0.0
for i in range(len(df_test2)):
    if df_test2['w_name'][i] in players_elo and df_test2['l_name'][i] in players_elo:
        if players_elo[df_test2['w_name'][i]].value - players_elo[df_test2['l_name'][i]].value > 0:
            sumofright = sumofright + 1


sumofright/len(df_test2)
# Out:
# 436
# 100
# 0.6219236209335219
